# %%
5+6
# Out:
# 11

# %%
# !pip install pandas
import pandas as pd
df=pd.read_csv("locations.csv")
df
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\admin\appdata\roaming\python\python312\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# 11  12                3         disabled_parking, elevator, ramp, restroom
# 12  13                3                                                NaN
# 13  14                4                                         wheelchair
# 14  15                4                                         wheelchair
# 15  16                4                                                NaN
# 16  17                4                                         wheelchair
# 17  18                5                           cd, restroom, wheelchair
# 18  19                5                         elevator, ramp, wheelchair
# 19  20                6                                                NaN
# 20  21                7                                 elevator, restroom
# 21  22                8             disabled_parking, restroom, wheelchair
#
#        admin_emails alternate_name  \
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# 5               NaN            NaN
# 6               NaN            NaN
# 7               NaN            NaN
# 8               NaN            NaN
# 9               NaN            NaN
# 10              NaN            NaN
# 11  ohana@gmail.com            NaN
# 12              NaN            NaN
# 13              NaN            NaN
# 14              NaN            NaN
# 15              NaN            NaN
# 16              NaN            NaN
# 17              NaN            NaN
# 18              NaN            NaN
# 19              NaN            NaN
# 20              NaN            NaN
# 21      foo@bar.com  The Test Spot
#
#                                           description             email  \
# 0   A walk-in center for older adults that provide...               NaN
# 1   Provides training and job placement to eligibl...               NaN
# 2   Offers supportive counseling services to San M...               NaN
# 3   Provides supervised visitation services and a ...               NaN
# 4   Provides fixed 8% short term loans to eligible...               NaN
# 5   A multipurpose center offering a wide variety ...               NaN
# 6   Rosener House is a day center for older adults...               NaN
# 7   Delivers a hot meal to the home of persons age...               NaN
# 8   Provides general reading material, including b...               NaN
# 9   Provides general reading and media materials, ...               NaN
# 10  Provides general reading materials, including ...               NaN
# 11  Offers an intergenerational literacy program f...               NaN
# 12  Provides general reading materials, including ...               NaN
# 13  Provides food, clothing, bus tokens and shelte...               NaN
# 14  Provides a long-term (6-12 month) residential ...               NaN
# 15  Provides emergency assistance including food a...               NaN
# 16  Provides emergency food, clothing and furnitur...               NaN
# 17  Provides free medical care to those in need. O...               NaN
# 18  Provides free medical and dental care to those...               NaN
# 19                                           no phone               NaN
# 20                              This is a description               NaN
# 21  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...  info@example.org
#
#                                             languages   latitude   longitude  \
# 0                                    Spanish, Tagalog  37.477227 -122.213221
# 1       Chinese (Mandarin), Tagalog, Italian, Spanish  37.563984 -122.325799
# 2   Chinese (Cantonese), Chinese (Mandarin), Tagal...  37.563984 -122.325799
# 3                                             Spanish  37.563984 -122.325799
# 4                                      Hindi, Spanish  37.563984 -122.325799
# 5                                    Tagalog, Spanish  37.448020 -122.180590
# 6                        Spanish, Tagalog, Vietnamese  37.444178 -122.183093
# 7                                             Spanish  37.448020 -122.180590
# 8                                             Spanish  37.478502 -122.214143
# 9                                             Spanish  37.483842 -122.227395
# 10                                                NaN  37.466553 -122.243090
# 11                                                NaN  37.483842 -122.227395
# 12                                                NaN  37.530423 -122.258643
# 13                                            Spanish  37.491386 -122.231568
# 14                                            Spanish  37.748899 -122.420367
# 15                                             Korean  37.356900 -122.060002
# 16                                                NaN  37.644590 -122.422490
# 17                                            Spanish  37.468614 -122.206798
# 18                                            Spanish  37.532694 -122.293124
# 19                                                NaN        NaN         NaN
# 20                                                NaN  37.529194 -122.287161
# 21    Cantonese, Russian, Spanish, Tagalog, Taiwanese  37.772640 -122.409915
#
#                                    name  \
# 0       Fair Oaks Adult Activity Center
# 1      Second Career Employment Program
# 2                Senior Peer Counseling
# 3              Family Visitation Center
# 4   Economic Self - Sufficiency Program
# 5                          Little House
# 6      Rosener House Adult Day Services
# 7        Meals on Wheels - South County
# 8                      Fair Oaks Branch
# 9                          Main Library
# 10                      Schaberg Branch
# 11                         Project Read
# 12                Redwood Shores Branch
# 13                   Redwood City Corps
# 14          Adult Rehabilitation Center
# 15                      Sunnyvale Corps
# 16    South San Francisco Citadel Corps
# 17     Redwood City Free Medical Clinic
# 18        San Mateo Free Medical Clinic
# 19               Location with no phone
# 20                  Admin Test Location
# 21                     Example Location
#
#                                            short_desc  \
# 0   A multipurpose senior citizens' center serving...
# 1   Provides training and job placement to eligibl...
# 2   Offers supportive counseling services to older...
# 3   Provides supervised visitation services and a ...
# 4              Makes small loans to working families.
# 5             A multipurpose senior citizens' center.
# 6             A day center for adults age 50 or over.
# 7   Will deliver a hot meal to the home of persons...
# 8   Provides general reading materials and referen...
# 9   Provides general reference and reading materia...
# 10  Provides general reading materials and referen...
# 11  Offers an intergenerational literacy program f...
# 12  Provides general reading materials and referen...
# 13  Provides a variety of emergency services to lo...
# 14  Long-term (6-12 month) residential treatment p...
# 15  Provides emergency assistance to persons in im...
# 16  Provides emergency food and clothing and furni...
# 17       Provides free medical care to those in need.
# 18  Provides free medical and dental care to those...
# 19                                           no phone
# 20                        This is a short description
# 21  [NOTE THIS IS NOT A REAL ENTRY--THIS IS FOR TE...
#
#                                        transportation  \
# 0                            SAMTRANS stops in front.
# 1   SAMTRANS stops within 1 block, CALTRAIN stops ...
# 2   Service is provided in person's home or at a m...
# 3   SAMTRANS stops within 1 block, CALTRAIN stops ...
# 4   SAMTRANS stops within 1 block. CALTRAIN stops ...
# 5   SAMTRANS stops within 3 blocks, RediWheels and...
# 6   Transportation can be arranged via Redi-Wheels...
# 7                          Not necessary for service.
# 8                            SAMTRANS stops in front.
# 9   SAMTRANS stops within 1 block; CALTRAIN stops ...
# 10                     SAMTRANS stops within 1 block.
# 11                     SAMTRANS stops within 1 block.
# 12                                                NaN
# 13                             SAMTRANS stops nearby.
# 14          MUNI - 26 Valencia, Mission Street lines.
# 15                         VTA stops within 4 blocks.
# 16  SAMTRANS stops within 1 block, BART stops with...
# 17                    SAMTRANS stops within 2 blocks.
# 18                     SAMTRANS stops within 1 block.
# 19                                                NaN
# 20                    SAMTRANS stops within 1/2 mile.
# 21                      SAMTRANS stops within 1 block
#
#                           website  virtual
# 0                             NaN    False
# 1                             NaN    False
# 2                             NaN    False
# 3                             NaN    False
# 4                             NaN    False
# 5                             NaN    False
# 6                             NaN    False
# 7                             NaN    False
# 8                             NaN    False
# 9                             NaN    False
# 10                            NaN    False
# 11                            NaN    False
# 12                            NaN    False
# 13                            NaN    False
# 14                            NaN    False
# 15                            NaN    False
# 16                            NaN    False
# 17  http://www.samaritanhouse.com    False
# 18  http://www.samaritanhouse.com    False
# 19                            NaN     True
# 20                            NaN    False
# 21         http://www.example.org    False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               22 non-null     int64
#  1   organization_id  22 non-null     int64
#  2   accessibility    17 non-null     object
#  3   admin_emails     2 non-null      object
#  4   alternate_name   1 non-null      object
#  5   description      22 non-null     object
#  6   email            1 non-null      object
#  7   languages        16 non-null     object
#  8   latitude         21 non-null     float64
#  9   longitude        21 non-null     float64
#  10  name             22 non-null     object
#  11  short_desc       22 non-null     object
#  12  transportation   20 non-null     object
#  13  website          3 non-null      object
#  14  virtual          22 non-null     bool
# dtypes: bool(1), float64(2), int64(2), object(10)
# memory usage: 2.6+ KB

# %%
df.head(10)
# Out:
#    id  organization_id                                      accessibility  \
# 0   1                1       disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                         wheelchair
# 2   3                1                                                NaN
# 3   4                1                                         wheelchair
# 4   5                1                                         wheelchair
# 5   6                2                       disabled_parking, wheelchair
# 6   7                2       ramp, restroom, disabled_parking, wheelchair
# 7   8                2                                                NaN
# 8   9                3                         ramp, restroom, wheelchair
# 9  10                3  elevator, tape_braille, ramp, restroom, disabl...
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
# 5          NaN            NaN
# 6          NaN            NaN
# 7          NaN            NaN
# 8          NaN            NaN
# 9          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
# 2  Offers supportive counseling services to San M...   NaN
# 3  Provides supervised visitation services and a ...   NaN
# 4  Provides fixed 8% short term loans to eligible...   NaN
# 5  A multipurpose center offering a wide variety ...   NaN
# 6  Rosener House is a day center for older adults...   NaN
# 7  Delivers a hot meal to the home of persons age...   NaN
# 8  Provides general reading material, including b...   NaN
# 9  Provides general reading and media materials, ...   NaN
#
#                                            languages   latitude   longitude  \
# 0                                   Spanish, Tagalog  37.477227 -122.213221
# 1      Chinese (Mandarin), Tagalog, Italian, Spanish  37.563984 -122.325799
# 2  Chinese (Cantonese), Chinese (Mandarin), Tagal...  37.563984 -122.325799
# 3                                            Spanish  37.563984 -122.325799
# 4                                     Hindi, Spanish  37.563984 -122.325799
# 5                                   Tagalog, Spanish  37.448020 -122.180590
# 6                       Spanish, Tagalog, Vietnamese  37.444178 -122.183093
# 7                                            Spanish  37.448020 -122.180590
# 8                                            Spanish  37.478502 -122.214143
# 9                                            Spanish  37.483842 -122.227395
#
#                                   name  \
# 0      Fair Oaks Adult Activity Center
# 1     Second Career Employment Program
# 2               Senior Peer Counseling
# 3             Family Visitation Center
# 4  Economic Self - Sufficiency Program
# 5                         Little House
# 6     Rosener House Adult Day Services
# 7       Meals on Wheels - South County
# 8                     Fair Oaks Branch
# 9                         Main Library
#
#                                           short_desc  \
# 0  A multipurpose senior citizens' center serving...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to older...
# 3  Provides supervised visitation services and a ...
# 4             Makes small loans to working families.
# 5            A multipurpose senior citizens' center.
# 6            A day center for adults age 50 or over.
# 7  Will deliver a hot meal to the home of persons...
# 8  Provides general reading materials and referen...
# 9  Provides general reference and reading materia...
#
#                                       transportation website  virtual
# 0                           SAMTRANS stops in front.     NaN    False
# 1  SAMTRANS stops within 1 block, CALTRAIN stops ...     NaN    False
# 2  Service is provided in person's home or at a m...     NaN    False
# 3  SAMTRANS stops within 1 block, CALTRAIN stops ...     NaN    False
# 4  SAMTRANS stops within 1 block. CALTRAIN stops ...     NaN    False
# 5  SAMTRANS stops within 3 blocks, RediWheels and...     NaN    False
# 6  Transportation can be arranged via Redi-Wheels...     NaN    False
# 7                         Not necessary for service.     NaN    False
# 8                           SAMTRANS stops in front.     NaN    False
# 9  SAMTRANS stops within 1 block; CALTRAIN stops ...     NaN    False

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\admin\appdata\roaming\python\python312\site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\admin\appdata\roaming\python\python312\site-packages (from seaborn) (2.2.2)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.53.1-cp312-cp312-win_amd64.whl.metadata (165 kB)
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ------- ------------------------------- 30.7/165.9 kB 1.3 MB/s eta 0:00:01
#      -------------------------------- ----- 143.4/165.9 kB 2.1 MB/s eta 0:00:01
#      -------------------------------------- 165.9/165.9 kB 2.0 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    -------------------- ------------------- 153.6/294.9 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 3.6 MB/s eta 0:00:00
# Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/7.8 MB 11.8 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.1/7.8 MB 9.5 MB/s eta 0:00:01
#    ------- -------------------------------- 1.5/7.8 MB 10.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/7.8 MB 11.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.2/7.8 MB 10.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.2/7.8 MB 10.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.4/7.8 MB 9.9 MB/s eta 0:00:01
#    -------------------- ------------------- 3.9/7.8 MB 10.5 MB/s eta 0:00:01
#    --------------------- ------------------ 4.2/7.8 MB 10.4 MB/s eta 0:00:01
#    --------------------- ------------------ 4.2/7.8 MB 10.4 MB/s eta 0:00:01
#    --------------------------- ------------ 5.4/7.8 MB 10.2 MB/s eta 0:00:01
#    ------------------------------- -------- 6.1/7.8 MB 10.2 MB/s eta 0:00:01
#    --------------------------------- ------ 6.6/7.8 MB 10.3 MB/s eta 0:00:01
#    ------------------------------------ --- 7.1/7.8 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------  7.7/7.8 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 10.0 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl (189 kB)
#    ---------------------------------------- 0.0/189.9 kB ? eta -:--:--
#    --------------------------------------- 189.9/189.9 kB 11.2 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.1-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.4/2.2 MB 13.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.9/2.2 MB 11.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.4/2.2 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.9/2.2 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 2.0/2.2 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 7.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/56.0 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 56.0/56.0 kB 579.3 kB/s eta 0:00:00
# Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    --------- ------------------------------ 0.6/2.6 MB 18.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.1/2.6 MB 12.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.5/2.6 MB 11.6 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.6 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 10.9 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.2 pillow-10.4.0 pyparsing-3.1.2 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\admin\appdata\roaming\python\python312\site-packages (from scikit-learn) (2.0.1)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.8 kB 320.0 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 537.6 kB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.5.1-cp312-cp312-win_amd64.whl (10.9 MB)
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.9 MB 2.4 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/10.9 MB 2.8 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/10.9 MB 3.7 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/10.9 MB 5.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/10.9 MB 6.0 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/10.9 MB 7.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.8/10.9 MB 7.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.8/10.9 MB 7.7 MB/s eta 0:00:02
#    ------------- -------------------------- 3.7/10.9 MB 8.1 MB/s eta 0:00:01
#    ------------- -------------------------- 3.7/10.9 MB 8.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.7/10.9 MB 8.3 MB/s eta 0:00:01
#    ------------------ --------------------- 5.1/10.9 MB 8.3 MB/s eta 0:00:01
#    ------------------- -------------------- 5.4/10.9 MB 8.3 MB/s eta 0:00:01
#    --------------------- ------------------ 5.9/10.9 MB 8.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.4/10.9 MB 8.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/10.9 MB 8.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/10.9 MB 8.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.8/10.9 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.2/10.9 MB 8.7 MB/s eta 0:00:01
#    ------------------------------- -------- 8.6/10.9 MB 8.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.1/10.9 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.5/10.9 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/10.9 MB 8.9 MB/s eta 0:00:01
#    ------------------------------------- -- 10.4/10.9 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  10.9/10.9 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  10.9/10.9 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.9/10.9 MB 9.3 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    ---------------------------------------- 301.8/301.8 kB 9.1 MB/s eta 0:00:00
# Downloading scipy-1.14.1-cp312-cp312-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.5/44.5 MB 10.2 MB/s eta 0:00:05
#     --------------------------------------- 1.0/44.5 MB 10.4 MB/s eta 0:00:05
#    - -------------------------------------- 1.4/44.5 MB 10.2 MB/s eta 0:00:05
#    - -------------------------------------- 1.8/44.5 MB 9.6 MB/s eta 0:00:05
#    -- ------------------------------------- 2.4/44.5 MB 10.1 MB/s eta 0:00:05
#    -- ------------------------------------- 2.6/44.5 MB 9.8 MB/s eta 0:00:05
#    -- ------------------------------------- 3.0/44.5 MB 9.2 MB/s eta 0:00:05
#    --- ------------------------------------ 3.5/44.5 MB 9.4 MB/s eta 0:00:05
#    --- ------------------------------------ 4.1/44.5 MB 9.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.5/44.5 MB 9.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 5.1/44.5 MB 9.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 5.4/44.5 MB 9.5 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.9/44.5 MB 9.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 6.4/44.5 MB 9.7 MB/s eta 0:00:04
#    ------ --------------------------------- 6.8/44.5 MB 9.7 MB/s eta 0:00:04
#    ------ --------------------------------- 7.4/44.5 MB 9.8 MB/s eta 0:00:04
#    ------- -------------------------------- 7.8/44.5 MB 9.8 MB/s eta 0:00:04
#    ------- -------------------------------- 8.4/44.5 MB 9.9 MB/s eta 0:00:04
#    ------- -------------------------------- 8.7/44.5 MB 9.7 MB/s eta 0:00:04
#    -------- ------------------------------- 9.2/44.5 MB 9.8 MB/s eta 0:00:04
#    -------- ------------------------------- 9.3/44.5 MB 9.6 MB/s eta 0:00:04
#    -------- ------------------------------- 9.7/44.5 MB 9.4 MB/s eta 0:00:04
#    --------- ------------------------------ 10.1/44.5 MB 9.5 MB/s eta 0:00:04
#    --------- ------------------------------ 10.6/44.5 MB 9.5 MB/s eta 0:00:04
#    --------- ------------------------------ 10.7/44.5 MB 9.5 MB/s eta 0:00:04
#    --------- ------------------------------ 11.1/44.5 MB 9.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 11.6/44.5 MB 9.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 12.0/44.5 MB 9.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 12.6/44.5 MB 9.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 13.0/44.5 MB 9.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 13.1/44.5 MB 9.0 MB/s eta 0:00:04
#    ------------ --------------------------- 13.6/44.5 MB 9.1 MB/s eta 0:00:04
#    ------------ --------------------------- 14.1/44.5 MB 9.1 MB/s eta 0:00:04
#    ------------- -------------------------- 14.6/44.5 MB 9.1 MB/s eta 0:00:04
#    ------------- -------------------------- 15.1/44.5 MB 9.1 MB/s eta 0:00:04
#    -------------- ------------------------- 15.6/44.5 MB 9.4 MB/s eta 0:00:04
#    -------------- ------------------------- 16.1/44.5 MB 9.2 MB/s eta 0:00:04
#    -------------- ------------------------- 16.6/44.5 MB 9.2 MB/s eta 0:00:04
#    --------------- ------------------------ 17.1/44.5 MB 9.2 MB/s eta 0:00:03
#    --------------- ------------------------ 17.6/44.5 MB 9.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 18.1/44.5 MB 9.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 18.6/44.5 MB 9.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 19.1/44.5 MB 9.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 19.5/44.5 MB 9.5 MB/s eta 0:00:03
#    ------------------ --------------------- 20.1/44.5 MB 9.8 MB/s eta 0:00:03
#    ------------------ --------------------- 20.5/44.5 MB 9.8 MB/s eta 0:00:03
#    ------------------ --------------------- 21.0/44.5 MB 10.1 MB/s eta 0:00:03
#    ------------------- -------------------- 21.5/44.5 MB 10.2 MB/s eta 0:00:03
#    ------------------- -------------------- 22.1/44.5 MB 10.2 MB/s eta 0:00:03
#    -------------------- ------------------- 22.5/44.5 MB 10.2 MB/s eta 0:00:03
#    -------------------- ------------------- 23.0/44.5 MB 10.2 MB/s eta 0:00:03
#    --------------------- ------------------ 23.6/44.5 MB 10.7 MB/s eta 0:00:02
#    --------------------- ------------------ 24.1/44.5 MB 10.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 24.7/44.5 MB 10.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 25.1/44.5 MB 10.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 25.7/44.5 MB 10.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 26.2/44.5 MB 10.9 MB/s eta 0:00:02
#    ------------------------ --------------- 26.8/44.5 MB 10.9 MB/s eta 0:00:02
#    ------------------------ --------------- 27.4/44.5 MB 11.1 MB/s eta 0:00:02
#    ------------------------- -------------- 27.9/44.5 MB 11.1 MB/s eta 0:00:02
#    ------------------------- -------------- 28.4/44.5 MB 11.3 MB/s eta 0:00:02
#    -------------------------- ------------- 29.0/44.5 MB 11.3 MB/s eta 0:00:02
#    -------------------------- ------------- 29.5/44.5 MB 11.3 MB/s eta 0:00:02
#    -------------------------- ------------- 29.9/44.5 MB 11.3 MB/s eta 0:00:02
#    --------------------------- ------------ 30.5/44.5 MB 11.3 MB/s eta 0:00:02
#    --------------------------- ------------ 31.0/44.5 MB 11.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 31.6/44.5 MB 11.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 32.1/44.5 MB 11.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 32.6/44.5 MB 11.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.2/44.5 MB 11.5 MB/s eta 0:00:01
#    ------------------------------ --------- 33.6/44.5 MB 11.3 MB/s eta 0:00:01
#    ------------------------------ --------- 34.1/44.5 MB 11.3 MB/s eta 0:00:01
#    ------------------------------- -------- 34.5/44.5 MB 11.3 MB/s eta 0:00:01
#    ------------------------------- -------- 35.1/44.5 MB 11.3 MB/s eta 0:00:01
#    -------------------------------- ------- 35.7/44.5 MB 11.3 MB/s eta 0:00:01
#    -------------------------------- ------- 36.3/44.5 MB 11.3 MB/s eta 0:00:01
#    --------------------------------- ------ 36.8/44.5 MB 11.3 MB/s eta 0:00:01
#    --------------------------------- ------ 37.4/44.5 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 37.9/44.5 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.5/44.5 MB 11.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.0/44.5 MB 11.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.6/44.5 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ --- 40.1/44.5 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ --- 40.7/44.5 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------- -- 41.2/44.5 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------- -- 41.6/44.5 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------- -- 41.9/44.5 MB 11.3 MB/s eta 0:00:01
#    -------------------------------------- - 42.4/44.5 MB 11.1 MB/s eta 0:00:01
#    -------------------------------------- - 42.6/44.5 MB 10.7 MB/s eta 0:00:01
#    -------------------------------------- - 43.1/44.5 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  43.7/44.5 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.5 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  44.5/44.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 8.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.1 scipy-1.14.1 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()
df = pd.DataFrame(housing.data, columns=housing.feature_names)
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
df["Price"]=housing.target
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# 4        -122.25  3.422
# ...          ...    ...
# 20635    -121.09  0.781
# 20636    -121.21  0.771
# 20637    -121.22  0.923
# 20638    -121.32  0.847
# 20639    -121.24  0.894
#
# [20640 rows x 9 columns]
